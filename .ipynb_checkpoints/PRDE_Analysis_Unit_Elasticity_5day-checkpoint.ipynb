# %%
from cw_analysis import calculate_ppc, process_multiple_ppc, make_array, normal_distribution_tests, find_best_mean

import matplotlib.pyplot as plt
import numpy as np
import csv
import math
import random

import pandas as pd
from matplotlib import style
from matplotlib.pyplot import cm
import matplotlib.collections as mcoll

import seaborn as sns
from scipy.stats import kurtosis, skew
from scipy import stats
import statistics

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 5 Day Trials

# %% [markdown]
# ## All results

# %%
all_sma_set_k7_5d = process_multiple_ppc('unit_elastic/set_k7_5d/set_k7_%01.1f_trail',0.0,2.0,0.1,
                                      'unit_elastic/set_k7_5d/figures/total_all_f.png', 
                                      'Profit: PRDE with fixed K=7 and F=')

# %%
all_sma_set_k7_5d = make_array(all_sma_set_k7_5d)

# %% [markdown]
# ### Distribution Analysis

# %%
normal_distribution_tests(all_sma_set_k7_5d, False)
# Out:
# C:\Users\linda\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# skewness of normal distribution (should be 0): -3.5098720705340747
# shapiro of normal distribution (p should be > 0.5):0.000000000000000007119694079115
# median of data: 46.002153
#
# skewness of normal distribution (should be 0): -3.799740275145287
# shapiro of normal distribution (p should be > 0.5):0.000000000000000004751965676299
# median of data: 41.914817
#
# skewness of normal distribution (should be 0): -3.9609906633109286
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000714595799414
# median of data: 45.007738
#
# skewness of normal distribution (should be 0): -4.275265629864376
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000327239552114
# median of data: 39.128553
#
# skewness of normal distribution (should be 0): -3.758346233260296
# shapiro of normal distribution (p should be > 0.5):0.000000000000000001603397283398
# median of data: 40.614417
#
# skewness of normal distribution (should be 0): -3.80346712977014
# shapiro of normal distribution (p should be > 0.5):0.000000000000000003191387500707
# median of data: 43.734449
#
# skewness of normal distribution (should be 0): -4.194415842802342
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000175530129977
# median of data: 41.918350
#
# skewness of normal distribution (should be 0): -4.312913280609755
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000181770781184
# median of data: 43.194901
#
# skewness of normal distribution (should be 0): -3.7872335142644324
# shapiro of normal distribution (p should be > 0.5):0.000000000000000004245798970226
# median of data: 45.573002
#
# skewness of normal distribution (should be 0): -3.7633100639029666
# shapiro of normal distribution (p should be > 0.5):0.000000000000000002185698210038
# median of data: 46.910493
#
# skewness of normal distribution (should be 0): -3.9044215095077366
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000678238678252
# median of data: 47.091858
#
# skewness of normal distribution (should be 0): -3.810896919808343
# shapiro of normal distribution (p should be > 0.5):0.000000000000000003784099425934
# median of data: 46.021046
#
# skewness of normal distribution (should be 0): -3.3984407875537253
# shapiro of normal distribution (p should be > 0.5):0.000000000000000032473152085141
# median of data: 46.503833
#
# skewness of normal distribution (should be 0): -3.3933090519794673
# shapiro of normal distribution (p should be > 0.5):0.000000000000000023354066512534
# median of data: 48.687350
#
# skewness of normal distribution (should be 0): -3.1612321466132327
# shapiro of normal distribution (p should be > 0.5):0.000000000000000959833171873103
# median of data: 48.184763
#
# skewness of normal distribution (should be 0): -3.253854383934171
# shapiro of normal distribution (p should be > 0.5):0.000000000000000009215861568373
# median of data: 49.941434
#
# skewness of normal distribution (should be 0): -4.076496054248849
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000459065335933
# median of data: 49.400047
#
# skewness of normal distribution (should be 0): -3.634182606824914
# shapiro of normal distribution (p should be > 0.5):0.000000000000000014673949147397
# median of data: 49.448157
#
# skewness of normal distribution (should be 0): -4.158144550296661
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000334912505326
# median of data: 50.651053
#
# skewness of normal distribution (should be 0): -3.3087808841572257
# shapiro of normal distribution (p should be > 0.5):0.000000000000000118287423165124
# median of data: 50.764487

# %% [markdown]
# ### Mean Analysis

# %%
find_best_mean(all_sma_set_k7_5d, 0)

fig = plt.figure(figsize =(10, 7))
plt.boxplot(all_sma_set_k7_5d)
plt.show()
# Out:
# [42.782901304999996, 40.73724488666665, 42.83649064333331, 37.46706764500001, 38.73284827833333, 41.273431305000024, 39.99475681166667, 41.251849335, 43.319635425210095, 44.14593265, 44.21952690000001, 43.936601486666675, 44.35638646499999, 45.41047138833333, 45.90319790499999, 46.62302094166669, 47.216021465, 47.297884204999974, 48.270342520000014, 47.53747922166667]
# 18 48.270342520000014

# %% [markdown]
# ### ANOVA

# %%
from scipy.stats import f_oneway
f_oneway(all_sma_set_k7_5d[0], all_sma_set_k7_5d[1], all_sma_set_k7_5d[2], all_sma_set_k7_5d[3], all_sma_set_k7_5d[4] , all_sma_set_k7_5d[5],  all_sma_set_k7_5d[6], all_sma_set_k7_5d[7])
# Out:
# F_onewayResult(statistic=5.863680222359164, pvalue=1.1074043245338232e-06)

# %% [markdown]
# ### Kruskal-Wallis

# %%
k, p = stats.kruskal(all_sma_set_k7_5d[0], all_sma_set_k7_5d[1], all_sma_set_k7_5d[2], all_sma_set_k7_5d[3], all_sma_set_k7_5d[4] , all_sma_set_k7_5d[5],  
                     all_sma_set_k7_5d[6], all_sma_set_k7_5d[7], all_sma_set_k7_5d[8], all_sma_set_k7_5d[9], all_sma_set_k7_5d[10], all_sma_set_k7_5d[11],
                     all_sma_set_k7_5d[12], all_sma_set_k7_5d[13], all_sma_set_k7_5d[14], all_sma_set_k7_5d[15], all_sma_set_k7_5d[16], all_sma_set_k7_5d[17],
                     all_sma_set_k7_5d[18], all_sma_set_k7_5d[19])
print(p)
print(format(p, '.22f'))
# Out:
# 3.9584957564557436e-197
# 0.0000000000000000000000

# %% [markdown]
# ### Mann-whitney

# %%
from scipy.stats import norm
from scipy.stats import mannwhitneyu

res, p = mannwhitneyu(all_sma_set_k7_5d[0], all_sma_set_k7_5d[1])
print(format(p, '.11f'))
# Out:
# 0.00000000264

# %% [markdown]
# ## Individual Trials

# %%
# total = process_multiple_ppc('perfect_elastic/3d_set_f1.8_k5_trail',4,5,1,
#                                       'set_k/figures/total_all_f.png', 
#                                       'Profit: PRDE with fixed K=5 and F=1.8')

# calculate_ppc('perfect_elastic/3d_set_f1.8_k5_trail', 5, "title", True)
# np.mean(total[0])
