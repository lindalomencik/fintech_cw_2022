# %%
from cw_analysis import calculate_ppc, process_multiple_ppc, make_array, normal_distribution_tests, find_best_mean, find_best_median

import matplotlib.pyplot as plt
import numpy as np
import csv
import math
import random

import pandas as pd
from matplotlib import style
from matplotlib.pyplot import cm
import matplotlib.collections as mcoll

import seaborn as sns
from scipy.stats import kurtosis, skew
from scipy import stats
import statistics

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 3 Day Trials

# %% [markdown]
# ## All results

# %%
all_sma_set_f_3d = process_multiple_ppc('unit_elastic/set_f0.8_3d/set_f_%d',4,12,1,
                                        'unit_elastic/set_f0.8_3d/figures/total_all_k.png', 
                                        'Profit: PRDE with fixed F=0.8 and K=')

# %%
all_sma_set_f_3d = make_array(all_sma_set_f_3d)

# %% [markdown]
# ### Distribution Analysis

# %%
normal_distribution_tests(all_sma_set_f_3d, False)
# Out:
# C:\Users\linda\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# skewness of normal distribution (should be 0): -2.834474883138262
# shapiro of normal distribution (p should be > 0.5):0.000000000000454617056890385673
#
# skewness of normal distribution (should be 0): -3.254279974369631
# shapiro of normal distribution (p should be > 0.5):0.000000000000019860291728779171
#
# skewness of normal distribution (should be 0): -2.847820369397098
# shapiro of normal distribution (p should be > 0.5):0.000000000001951901531030419967
#
# skewness of normal distribution (should be 0): -3.329494278792559
# shapiro of normal distribution (p should be > 0.5):0.000000000000017557073619923168
#
# skewness of normal distribution (should be 0): -3.0988707601980834
# shapiro of normal distribution (p should be > 0.5):0.000000000000197526104630738053
#
# skewness of normal distribution (should be 0): -3.246556734609317
# shapiro of normal distribution (p should be > 0.5):0.000000000000051864891233762561
#
# skewness of normal distribution (should be 0): -2.699029588618138
# shapiro of normal distribution (p should be > 0.5):0.000000000000156753123393797711
#
# skewness of normal distribution (should be 0): -3.2191663240861286
# shapiro of normal distribution (p should be > 0.5):0.000000000000008555581644618254

# %% [markdown]
# ### Mean Analysis

# %%
find_best_mean(all_sma_set_f_3d, 4)

fig = plt.figure(figsize =(10, 7))
plt.boxplot(all_sma_set_f_3d)
plt.show()
# Out:
# [38.98708785555555, 41.621947469444436, 40.30814895555555, 39.42056858591549, 38.378450177777786, 38.40630349166665, 39.986133074999984, 39.19055628611112]
# 5 41.621947469444436

# %%
find_best_median(all_sma_set_f_3d, 4)
# Out:
# [43.254682599999995, 44.185350499999984, 42.098374699999994, 42.4187548, 41.120284200000015, 40.92777229999999, 43.36971879999998, 42.242910300000005]
# 5 44.185350499999984

# %% [markdown]
# ### ANOVA

# %%
from scipy.stats import f_oneway
f_oneway(all_sma_set_f_3d[0], all_sma_set_f_3d[1], all_sma_set_f_3d[2], all_sma_set_f_3d[3], all_sma_set_f_3d[4] , all_sma_set_f_3d[5],  all_sma_set_f_3d[6], all_sma_set_f_3d[7])
# Out:
# F_onewayResult(statistic=0.7595502703252903, pvalue=0.6215376234616976)

# %% [markdown]
# ### Kruskal-Wallis

# %%
k, p = stats.kruskal(all_sma_set_f_3d[0], all_sma_set_f_3d[1], all_sma_set_f_3d[2], all_sma_set_f_3d[3], all_sma_set_f_3d[4] , all_sma_set_f_3d[5],  all_sma_set_f_3d[6], all_sma_set_f_3d[7])
print(k)
print(format(p, '.22f'))
# Out:
# 61.20578690633218
# 0.0000000000866754593750

# %% [markdown]
# ### Mann-whitney

# %%
from scipy.stats import norm
from scipy.stats import mannwhitneyu

res, p = mannwhitneyu(all_sma_set_f_3d[0], all_sma_set_f_3d[1])
print(format(p, '.11f'))
# Out:
# 0.00009269649

# %% [markdown]
# ## Individual Trials

# %%
normal_distribution_tests(all_sma_set_f_3d[1:2], True)

# total = calculate_ppc('set_f1.8_k5_trail', 5, "title", True)
# np.mean(total[0])

# total = make_array(total)

# normal_distribution_tests(total[:1])
# Out:
# skewness of normal distribution (should be 0): -3.254279974369631
# shapiro of normal distribution (p should be > 0.5):0.000000000000019860291728779171
# median of data: 44.185350

# %% [markdown]
# # 5 day trials

# %%
all_sma_set_f_5d = process_multiple_ppc('unit_elastic/set_f0.8_5d/set_f_%d_trail',4,13,1,
                                        'unit_elastic/set_f0.8_5d/figures/total_all_k.png', 
                                        'Profit: PRDE with fixed F=0.8 and K=')

# %%
all_sma_set_f_5d = make_array(all_sma_set_f_5d)

# %%
normal_distribution_tests(all_sma_set_f_5d, False)
# Out:
# skewness of normal distribution (should be 0): -4.308724692462351
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000190008504883
# median of data: 44.608091
#
# skewness of normal distribution (should be 0): -3.3535156432795836
# shapiro of normal distribution (p should be > 0.5):0.000000000000000111731321978927
# median of data: 47.432022
#
# skewness of normal distribution (should be 0): -3.641820807183639
# shapiro of normal distribution (p should be > 0.5):0.000000000000000070188041832913
# median of data: 42.671060
#
# skewness of normal distribution (should be 0): -4.4224180636587525
# shapiro of normal distribution (p should be > 0.5):0.000000000000000000110085331822
# median of data: 44.967672
#
# skewness of normal distribution (should be 0): -3.2617109813066234
# shapiro of normal distribution (p should be > 0.5):0.000000000000000021332021850787
# median of data: 44.272500
#
# skewness of normal distribution (should be 0): -3.3072620545391365
# shapiro of normal distribution (p should be > 0.5):0.000000000000000046334138200354
# median of data: 42.744155
#
# skewness of normal distribution (should be 0): -3.288949835179599
# shapiro of normal distribution (p should be > 0.5):0.000000000000000110839555104146
# median of data: 44.952246
#
# skewness of normal distribution (should be 0): -3.8859540665634635
# shapiro of normal distribution (p should be > 0.5):0.000000000000000005696538520614
# median of data: 42.870114
#
# skewness of normal distribution (should be 0): -3.2125673898279867
# shapiro of normal distribution (p should be > 0.5):0.000000000000000273584918639120
# median of data: 42.118393

# %%
find_best_mean(all_sma_set_f_5d, 4)

fig = plt.figure(figsize =(10, 7))
plt.boxplot(all_sma_set_f_5d)
plt.show()
# Out:
# [42.69967226890758, 44.26719678333335, 40.97525004537814, 43.07000373613445, 41.670977055, 40.020067736666654, 42.703186661666656, 41.00063520166669, 40.07589549833334]
# 5 44.26719678333335

# %%
k, p = stats.kruskal(all_sma_set_f_5d[0], all_sma_set_f_5d[1], all_sma_set_f_5d[2], all_sma_set_f_5d[3], all_sma_set_f_5d[4] , all_sma_set_f_5d[5],  all_sma_set_f_5d[6], all_sma_set_f_5d[7], all_sma_set_f_5d[8])
# print(p)
print(format(p, '.30f'))
# Out:
# 0.000000000000000000000000109981
